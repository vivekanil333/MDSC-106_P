# %%
import pandas as pd
import seaborn as sns
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
Data1_df=pd.read_csv("Data1.csv")
Data1_df
# Out:
#         ID  Age  CustomerSince  HighestSpend  ZipCode  HiddenScore  \
# 0        1   25              1            49    91107            4
# 1        2   45             19            34    90089            3
# 2        3   39             15            11    94720            1
# 3        4   35              9           100    94112            1
# 4        5   35              8            45    91330            4
# ...    ...  ...            ...           ...      ...          ...
# 4995  4996   29              3            40    92697            1
# 4996  4997   30              4            15    92037            4
# 4997  4998   63             39            24    93023            2
# 4998  4999   65             40            49    90034            3
# 4999  5000   28              4            83    92612            3
#
#       MonthlyAverageSpend  Level
# 0                     1.6      1
# 1                     1.5      1
# 2                     1.0      1
# ...

# %%
Data2_df=pd.read_csv("Data2.csv")
Data2_df
# Out:
#         ID  Mortgage  Security  FixedDepositAccount  InternetBanking  \
# 0        1         0         1                    0                0
# 1        2         0         1                    0                0
# 2        3         0         0                    0                0
# 3        4         0         0                    0                0
# 4        5         0         0                    0                0
# ...    ...       ...       ...                  ...              ...
# 4995  4996         0         0                    0                1
# 4996  4997        85         0                    0                1
# 4997  4998         0         0                    0                0
# 4998  4999         0         0                    0                1
# 4999  5000         0         0                    0                1
#
#       CreditCard  LoanOnCard
# 0              0         NaN
# 1              0         NaN
# 2              0         NaN
# ...

# %%
shape=Data1_df.shape
shape
# Out:
# (5000, 8)

# %%
shape2=Data2_df.shape
shape2
# Out:
# (5000, 7)

# %%
columnnames_1=Data1_df.columns
columnnames_1
# Out:
# Index(['ID', 'Age', 'CustomerSince', 'HighestSpend', 'ZipCode', 'HiddenScore',
#        'MonthlyAverageSpend', 'Level'],
#       dtype='object')

# %%
columnnames_2=Data2_df.columns
columnnames_2
# Out:
# Index(['ID', 'Mortgage', 'Security', 'FixedDepositAccount', 'InternetBanking',
#        'CreditCard', 'LoanOnCard'],
#       dtype='object')

# %%
Data1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   5000 non-null   int64
#  1   Age                  5000 non-null   int64
#  2   CustomerSince        5000 non-null   int64
#  3   HighestSpend         5000 non-null   int64
#  4   ZipCode              5000 non-null   int64
#  5   HiddenScore          5000 non-null   int64
#  6   MonthlyAverageSpend  5000 non-null   float64
#  7   Level                5000 non-null   int64
# dtypes: float64(1), int64(7)
# memory usage: 312.6 KB

# %%
Data2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   5000 non-null   int64
#  1   Mortgage             5000 non-null   int64
#  2   Security             5000 non-null   int64
#  3   FixedDepositAccount  5000 non-null   int64
#  4   InternetBanking      5000 non-null   int64
#  5   CreditCard           5000 non-null   int64
#  6   LoanOnCard           4980 non-null   float64
# dtypes: float64(1), int64(6)
# memory usage: 273.6 KB

# %%
new_df = pd.merge(Data1_df, Data2_df, on='ID')
new_df
# Out:
#         ID  Age  CustomerSince  HighestSpend  ZipCode  HiddenScore  \
# 0        1   25              1            49    91107            4
# 1        2   45             19            34    90089            3
# 2        3   39             15            11    94720            1
# 3        4   35              9           100    94112            1
# 4        5   35              8            45    91330            4
# ...    ...  ...            ...           ...      ...          ...
# 4995  4996   29              3            40    92697            1
# 4996  4997   30              4            15    92037            4
# 4997  4998   63             39            24    93023            2
# 4998  4999   65             40            49    90034            3
# 4999  5000   28              4            83    92612            3
#
#       MonthlyAverageSpend  Level  Mortgage  Security  FixedDepositAccount  \
# 0                     1.6      1         0         1                    0
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   5000 non-null   int64
#  1   Age                  5000 non-null   int64
#  2   CustomerSince        5000 non-null   int64
#  3   HighestSpend         5000 non-null   int64
#  4   ZipCode              5000 non-null   int64
#  5   HiddenScore          5000 non-null   int64
#  6   MonthlyAverageSpend  5000 non-null   float64
#  7   Level                5000 non-null   int64
#  8   Mortgage             5000 non-null   int64
#  9   Security             5000 non-null   int64
#  10  FixedDepositAccount  5000 non-null   int64
#  11  InternetBanking      5000 non-null   int64
#  12  CreditCard           5000 non-null   int64
#  13  LoanOnCard           4980 non-null   float64
# dtypes: float64(2), int64(12)
# memory usage: 585.9 KB

# %%
columns_to_change = ['CreditCard', 'InternetBanking', 'FixedDepositAccount','Security','Level','HiddenScore']
new_df[columns_to_change]=new_df[columns_to_change].astype(str)
new_df
# Out:
#         ID  Age  CustomerSince  HighestSpend  ZipCode HiddenScore  \
# 0        1   25              1            49    91107           4
# 1        2   45             19            34    90089           3
# 2        3   39             15            11    94720           1
# 3        4   35              9           100    94112           1
# 4        5   35              8            45    91330           4
# ...    ...  ...            ...           ...      ...         ...
# 4995  4996   29              3            40    92697           1
# 4996  4997   30              4            15    92037           4
# 4997  4998   63             39            24    93023           2
# 4998  4999   65             40            49    90034           3
# 4999  5000   28              4            83    92612           3
#
#       MonthlyAverageSpend Level  Mortgage Security FixedDepositAccount  \
# 0                     1.6     1         0        1                   0
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   5000 non-null   int64
#  1   Age                  5000 non-null   int64
#  2   CustomerSince        5000 non-null   int64
#  3   HighestSpend         5000 non-null   int64
#  4   ZipCode              5000 non-null   int64
#  5   HiddenScore          5000 non-null   object
#  6   MonthlyAverageSpend  5000 non-null   float64
#  7   Level                5000 non-null   object
#  8   Mortgage             5000 non-null   int64
#  9   Security             5000 non-null   object
#  10  FixedDepositAccount  5000 non-null   object
#  11  InternetBanking      5000 non-null   object
#  12  CreditCard           5000 non-null   object
#  13  LoanOnCard           4980 non-null   float64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 585.9+ KB

# %%
sns.histplot(data=new_df, x='LoanOnCard', kde=True)  
plt.ylabel("count")
plt.xlabel("Loan on card")
plt.show()

# %%
sns.boxplot(data=new_df, x='LoanOnCard')
plt.xlabel('LoanOnCard')

plt.show()

# %%
null_values = new_df.isnull()
# Count the number of null values in each column
null_counts = null_values.sum()
print(null_counts)
# Out:
# ID                      0
# Age                     0
# CustomerSince           0
# HighestSpend            0
# ZipCode                 0
# HiddenScore             0
# MonthlyAverageSpend     0
# Level                   0
# Mortgage                0
# Security                0
# FixedDepositAccount     0
# InternetBanking         0
# CreditCard              0
# LoanOnCard             20
# dtype: int64

# %%
total_rows = new_df.shape[0]
null_percentage = (null_counts / total_rows) * 100
print(null_percentage)
# Out:
# ID                     0.0
# Age                    0.0
# CustomerSince          0.0
# HighestSpend           0.0
# ZipCode                0.0
# HiddenScore            0.0
# MonthlyAverageSpend    0.0
# Level                  0.0
# Mortgage               0.0
# Security               0.0
# FixedDepositAccount    0.0
# InternetBanking        0.0
# CreditCard             0.0
# LoanOnCard             0.4
# dtype: float64

# %%
new_df['LoanOnCard'].fillna(new_df['LoanOnCard'].mean(), inplace=True)
new_df.isnull().sum()
# Out:
# ID                     0
# Age                    0
# CustomerSince          0
# HighestSpend           0
# ZipCode                0
# HiddenScore            0
# MonthlyAverageSpend    0
# Level                  0
# Mortgage               0
# Security               0
# FixedDepositAccount    0
# InternetBanking        0
# CreditCard             0
# LoanOnCard             0
# dtype: int64

# %%
sns.histplot(data=new_df, x='LoanOnCard', kde=True)  
plt.ylabel("count")
plt.xlabel("Loan on card")
plt.show()

# %%
for column in new_df.columns:
    if pd.api.types.is_categorical_dtype(new_df[column]):
        unique_values = new_df[column].unique()
        print(f"Column '{column}':")
        for value in unique_values:
             print(value)

# %%
new_df
# Out:
#         ID  Age  CustomerSince  HighestSpend  ZipCode HiddenScore  \
# 0        1   25              1            49    91107           4
# 1        2   45             19            34    90089           3
# 2        3   39             15            11    94720           1
# 3        4   35              9           100    94112           1
# 4        5   35              8            45    91330           4
# ...    ...  ...            ...           ...      ...         ...
# 4995  4996   29              3            40    92697           1
# 4996  4997   30              4            15    92037           4
# 4997  4998   63             39            24    93023           2
# 4998  4999   65             40            49    90034           3
# 4999  5000   28              4            83    92612           3
#
#       MonthlyAverageSpend Level  Mortgage Security FixedDepositAccount  \
# 0                     1.6     1         0        1                   0
# ...

# %%
f = ["HiddenScore","Level", "Security", "FixedDepositAccount", "InternetBanking", "CreditCard", "LoanOnCard"]
# df.info()
df1 = new_df.copy()
# for i in f:
df1["InternetBanking"].astype(str)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   5000 non-null   int64
#  1   Age                  5000 non-null   int64
#  2   CustomerSince        5000 non-null   int64
#  3   HighestSpend         5000 non-null   int64
#  4   ZipCode              5000 non-null   int64
#  5   HiddenScore          5000 non-null   object
#  6   MonthlyAverageSpend  5000 non-null   float64
#  7   Level                5000 non-null   object
#  8   Mortgage             5000 non-null   int64
#  9   Security             5000 non-null   object
#  10  FixedDepositAccount  5000 non-null   object
#  11  InternetBanking      5000 non-null   object
#  12  CreditCard           5000 non-null   object
#  13  LoanOnCard           5000 non-null   float64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 585.9+ KB

# %%
sns.histplot(data = df1, x = "LoanOnCard", kde = True)
# Out:
# <Axes: xlabel='LoanOnCard', ylabel='Count'>

# %%
sns.countplot(x=df1["LoanOnCard"])
# Out:
# <Axes: xlabel='LoanOnCard', ylabel='count'>

# %%
sns.pairplot(df1,x_vars=["LoanOnCard"], hue="LoanOnCard")

# %% [markdown]
# ### HEATMAP ###

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df1.corr(numeric_only = False), annot = True)
# Out:
# <Axes: >

# %%
def Bar(df):
    df = new_df
    figure, axes = plt.subplots(2,3,figsize=(15,5))
    a,b = 0,0
    features = ['FixedDepositAccount','InternetBanking','CreditCard','LoanOnCard']
    for cols in new_df.columns:
        if cols in features:
            sns.barplot(new_df[cols],ax=axes[a,b])
            axes[a,b].set_title(f'Bar Plot for {cols}')
            b+=1
            if b>=3:
                b=0
                a+=1
                if a >= 2:
                    break 

Bar(new_df)                    
plt.show()

# %% [markdown]
# ### PAIRPLOT  FOR EACH OF THE SUBSET POSSIBLE ###

# %%
selected_features = ['Age', 'CustomerSince', 'HighestSpend', 'MonthlyAverageSpend', 'Mortgage']
df_subset = new_df[selected_features]
sns.pairplot(df_subset)
# plt.title('Pair Plot for each of the subsets possible')
plt.show()

# %% [markdown]
# ### PIE  CHART  MATRIX ###

# %%
import pandas as pd
import matplotlib.pyplot as plt

def pie_chart_matrix(dataframe, figsize=(12, 12)):
    features = new_df.select_dtypes(include=['object', 'category', 'bool'])
    num_features = len(features.columns)
    num_cols = int(num_features**0.5)
    num_rows = (num_features + num_cols - 1) // num_cols
    fig, axes = plt.subplots(num_rows, num_cols, figsize=figsize)
    axes = axes.ravel()
    
    for i, feature in enumerate(features.columns):
        counts = new_df[feature].value_counts()
        labels = counts.index
        sizes = counts.values
        axes[i].pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
        axes[i].set_title(f'Distribution of {feature}')
        axes[i].axis('equal')
    for i in range(num_features, num_cols * num_rows):
        fig.delaxes(axes[i])
    
    plt.tight_layout()
    plt.show()

# %%
pie_chart_matrix(new_df)
